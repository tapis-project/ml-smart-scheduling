# %%
import sys
sys.path.append('/home/jovyan/work/')
sys.path.append('/home/jovyan/work/src')
sys.path.append('/home/jovyan/work/src/data')
sys.path.append('/home/jovyan/work/src/features')

# %%
import sys
print(sys.path)
# Out:
# ['/home/jovyan/work/notebooks', '/opt/conda/lib/python311.zip', '/opt/conda/lib/python3.11', '/opt/conda/lib/python3.11/lib-dynload', '', '/opt/conda/lib/python3.11/site-packages', '/home/jovyan/work/', '/home/jovyan/work/src', '/home/jovyan/work/src/data', '/home/jovyan/work/src/features']

# %%
from src import data
from data import create_input_data
from data_explore import explore_util
from features import build_features

# %%
df = create_input_data.read_data(csv_file_name="../data/raw/anon_jobs_1Feb2022_1Aug2022_normal_sorted.csv", parse_dates_col=[4,5,6])
df
# Out:
#            jobid                                               user  \
# 0        9084275  5a1c85eb8bc9d4da20ce12b96ecc7bb9d79d3ef991e990...
# 1        9084279  b4b4df9343fe9f7110ec15863fb5df13fbd20268383ba9...
# 2        9084280  c593da51b38e5fd95cb891ec53a4b70c41ca189bf4b92d...
# 3        9084291  db3b1cee65585e6744e72478a737eafaa23ce99e81344e...
# 4        9084294  bb3cdc72e4a6895d67d00ccd3c9cf0f65bdc59f32dfa9e...
# ...          ...                                                ...
# 323211  10056827  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323212  10056828  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323213  10056829  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323214  10056831  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
# 323215  10056833  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
#
#                                                   account      state  \
# 0       38112a802292edea407a0678c9c75259cba6473c7acc62...  COMPLETED
# ...

# %%
opt_df=build_features.remove_cols(df,['jobid','user','reqcpus','nnodes','max_minutes','backlog_minutes',
                                      'backlog_num_jobs','running_num_jobs','running_minutes','account','state','run_minutes','nodelist'])

# %%
opt_df=opt_df.iloc[0:20,]
opt_df
# Out:
#                 submit               start                 end  queue_minutes
# 0  2022-02-01 00:10:00 2022-02-01 00:10:02 2022-02-01 18:10:39              0
# 1  2022-02-01 00:11:44 2022-02-01 07:44:39 2022-02-01 09:00:46            452
# 2  2022-02-01 00:12:27 2022-02-01 00:12:27 2022-02-01 00:12:39              0
# 3  2022-02-01 00:16:45 2022-02-01 04:43:31 2022-02-01 06:15:04            266
# 4  2022-02-01 00:17:49 2022-02-01 00:17:51 2022-02-01 00:58:55              0
# 5  2022-02-01 00:18:35 2022-02-01 00:18:36 2022-02-01 01:13:43              0
# 6  2022-02-01 00:20:34 2022-02-01 00:20:34 2022-02-01 01:51:34              0
# 7  2022-02-01 00:23:46 2022-02-01 04:55:24 2022-02-01 06:26:53            271
# 8  2022-02-01 00:31:31 2022-02-01 07:45:05 2022-02-01 10:53:40            433
# 9  2022-02-01 00:33:19 2022-02-01 00:33:21 2022-02-01 00:35:07              0
# 10 2022-02-01 00:35:00 2022-02-01 00:37:59 2022-02-01 02:02:00              2
# ...

# %%
from importlib import reload
reload(create_input_data)
lookback=75 #(10,rowsto discard: 13, (25,55),(35,55),(50,71),(75,192))
col_name="queue_minutes"
op_df,rows_to_discard=create_input_data.optimised_add_past_k_obs_insert(lookback, df,col_name)
# Out:
# *** loopback_count never equals to  lookback. so do not consider the row 0
# *** loopback_count never equals to  lookback. so do not consider the row 1
# *** loopback_count never equals to  lookback. so do not consider the row 2
# *** loopback_count never equals to  lookback. so do not consider the row 3
# *** loopback_count never equals to  lookback. so do not consider the row 4
# *** loopback_count never equals to  lookback. so do not consider the row 5
# *** loopback_count never equals to  lookback. so do not consider the row 6
# *** loopback_count never equals to  lookback. so do not consider the row 7
# *** loopback_count never equals to  lookback. so do not consider the row 8
# *** loopback_count never equals to  lookback. so do not consider the row 9
# *** loopback_count never equals to  lookback. so do not consider the row 10
# *** loopback_count never equals to  lookback. so do not consider the row 11
# ...

# %%
op_df
# Out:
#            jobid                                               user  \
# 0        9084275  5a1c85eb8bc9d4da20ce12b96ecc7bb9d79d3ef991e990...
# 1        9084279  b4b4df9343fe9f7110ec15863fb5df13fbd20268383ba9...
# 2        9084280  c593da51b38e5fd95cb891ec53a4b70c41ca189bf4b92d...
# 3        9084291  db3b1cee65585e6744e72478a737eafaa23ce99e81344e...
# 4        9084294  bb3cdc72e4a6895d67d00ccd3c9cf0f65bdc59f32dfa9e...
# ...          ...                                                ...
# 323211  10056827  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323212  10056828  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323213  10056829  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323214  10056831  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
# 323215  10056833  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
#
#                                                   account      state  \
# 0       38112a802292edea407a0678c9c75259cba6473c7acc62...  COMPLETED
# ...

# %%
rows_to_discard
# Out:
# 192

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/lookback75_anon_feb1_aug1.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
op_df.to_csv(filepath,index=False)

# %%
from importlib import reload
reload(create_input_data)
df_aug = create_input_data.read_data(csv_file_name="../data/raw/anon_jobs_1Aug2022_1Sept2022normal_sorted.csv", parse_dates_col=[4,5,6])

lookback=35 #(discard row 47 )
col_name="queue_minutes"
op_df,rows_to_discard=create_input_data.optimised_add_past_k_obs_insert(lookback, df_aug,col_name)
# Out:
# *** loopback_count never equals to  lookback. so do not consider the row 0
# *** loopback_count never equals to  lookback. so do not consider the row 1
# *** loopback_count never equals to  lookback. so do not consider the row 2
# *** loopback_count never equals to  lookback. so do not consider the row 3
# *** loopback_count never equals to  lookback. so do not consider the row 4
# *** loopback_count never equals to  lookback. so do not consider the row 5
# *** loopback_count never equals to  lookback. so do not consider the row 6
# *** loopback_count never equals to  lookback. so do not consider the row 7
# *** loopback_count never equals to  lookback. so do not consider the row 8
# *** loopback_count never equals to  lookback. so do not consider the row 9
# *** loopback_count never equals to  lookback. so do not consider the row 10
# *** loopback_count never equals to  lookback. so do not consider the row 11
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/lookback35_anon_aug1_sept1.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
op_df.to_csv(filepath,index=False)

# %%
from importlib import reload
reload(create_input_data)
df_sept = create_input_data.read_data(csv_file_name= "../data/raw/anon_jobs_1Sept2022_1Oct2022_normal_sorted.csv", parse_dates_col=[4,5,6])
lookback=35 #(discard row 42)
col_name="queue_minutes"
op_df,rows_to_discard=create_input_data.optimised_add_past_k_obs_insert(lookback, df_sept,col_name)
# Out:
# *** loopback_count never equals to  lookback. so do not consider the row 0
# *** loopback_count never equals to  lookback. so do not consider the row 1
# *** loopback_count never equals to  lookback. so do not consider the row 2
# *** loopback_count never equals to  lookback. so do not consider the row 3
# *** loopback_count never equals to  lookback. so do not consider the row 4
# *** loopback_count never equals to  lookback. so do not consider the row 5
# *** loopback_count never equals to  lookback. so do not consider the row 6
# *** loopback_count never equals to  lookback. so do not consider the row 7
# *** loopback_count never equals to  lookback. so do not consider the row 8
# *** loopback_count never equals to  lookback. so do not consider the row 9
# *** loopback_count never equals to  lookback. so do not consider the row 10
# *** loopback_count never equals to  lookback. so do not consider the row 11
# ...

# %%
op_df
# Out:
#           jobid                                               user  \
# 0      10202520  33dc82f5d7e2facb223e88a102e629700f8ef0f2157f0a...
# 1      10202521  33dc82f5d7e2facb223e88a102e629700f8ef0f2157f0a...
# 2      10202523  957171b261d4acdae7532fdb88a02c394208918481c215...
# 3      10202524  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 4      10202525  957171b261d4acdae7532fdb88a02c394208918481c215...
# ...         ...                                                ...
# 78903  10362530  d0184bde51d229b96acfc69db68e503171dfa0c2743ade...
# 78904  10362531  d0184bde51d229b96acfc69db68e503171dfa0c2743ade...
# 78905  10362532  d0184bde51d229b96acfc69db68e503171dfa0c2743ade...
# 78906  10362533  d0184bde51d229b96acfc69db68e503171dfa0c2743ade...
# 78907  10362534  d0184bde51d229b96acfc69db68e503171dfa0c2743ade...
#
#                                                  account      state  \
# 0      fad8925cc9b13df0251c48f6ffe1e39c2f7dca981137bb...  COMPLETED
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/lookback35_anon_sept1_oct1.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
op_df.to_csv(filepath,index=False)

# %%
from importlib import reload
reload(create_input_data)
df_oct = create_input_data.read_data(csv_file_name="../data/raw/anon_jobs_1Oct2022_1Nov2022_normal_sorted.csv", parse_dates_col=[4,5,6])
df_oct
lookback=35 #(discard row 54)
col_name="queue_minutes"
op_df,rows_to_discard=create_input_data.optimised_add_past_k_obs_insert(lookback, df_oct,col_name)
# Out:
# *** loopback_count never equals to  lookback. so do not consider the row 0
# *** loopback_count never equals to  lookback. so do not consider the row 1
# *** loopback_count never equals to  lookback. so do not consider the row 2
# *** loopback_count never equals to  lookback. so do not consider the row 3
# *** loopback_count never equals to  lookback. so do not consider the row 4
# *** loopback_count never equals to  lookback. so do not consider the row 5
# *** loopback_count never equals to  lookback. so do not consider the row 6
# *** loopback_count never equals to  lookback. so do not consider the row 7
# *** loopback_count never equals to  lookback. so do not consider the row 8
# *** loopback_count never equals to  lookback. so do not consider the row 9
# *** loopback_count never equals to  lookback. so do not consider the row 10
# *** loopback_count never equals to  lookback. so do not consider the row 11
# ...

# %%
op_df
# Out:
#           jobid                                               user  \
# 0      10362537  5120327f03a93e5a25d7f703cb028aaf88907b099f58a7...
# 1      10362538  5120327f03a93e5a25d7f703cb028aaf88907b099f58a7...
# 2      10362543  f4758641d564f65ff90e9ae957a6f16651f0c7c4e2ac9e...
# 3      10362544  f4758641d564f65ff90e9ae957a6f16651f0c7c4e2ac9e...
# 4      10362568  d0184bde51d229b96acfc69db68e503171dfa0c2743ade...
# ...         ...                                                ...
# 41659  10479353  b065dc6b494064591b0234096942cb09481a37201c2388...
# 41660  10479354  a920b593f0d515f0486e0b7ddc9120468160f65c78fcda...
# 41661  10479363  a920b593f0d515f0486e0b7ddc9120468160f65c78fcda...
# 41662  10479367  b065dc6b494064591b0234096942cb09481a37201c2388...
# 41663  10479368  a920b593f0d515f0486e0b7ddc9120468160f65c78fcda...
#
#                                                  account      state  \
# 0      540a448cc8f3edadb5fa75816a7b85805e55e678003009...  COMPLETED
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/lookback35_anon_oct1_nov1.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
op_df.to_csv(filepath,index=False)

# %%
from importlib import reload
reload(create_input_data)
df_nov = create_input_data.read_data(csv_file_name="../data/raw/anon_jobs_1Nov2022_1Dec2022_normal_sorted.csv", parse_dates_col=[4,5,6])
df_nov
lookback=35 #(discard row 75)
col_name="queue_minutes"
op_df,rows_to_discard=create_input_data.optimised_add_past_k_obs_insert(lookback, df_nov,col_name)
# Out:
# *** loopback_count never equals to  lookback. so do not consider the row 0
# *** loopback_count never equals to  lookback. so do not consider the row 1
# *** loopback_count never equals to  lookback. so do not consider the row 2
# *** loopback_count never equals to  lookback. so do not consider the row 3
# *** loopback_count never equals to  lookback. so do not consider the row 4
# *** loopback_count never equals to  lookback. so do not consider the row 5
# *** loopback_count never equals to  lookback. so do not consider the row 6
# *** loopback_count never equals to  lookback. so do not consider the row 7
# *** loopback_count never equals to  lookback. so do not consider the row 8
# *** loopback_count never equals to  lookback. so do not consider the row 9
# *** loopback_count never equals to  lookback. so do not consider the row 10
# *** loopback_count never equals to  lookback. so do not consider the row 11
# ...

# %%
op_df
# Out:
#           jobid                                               user  \
# 0      10479394  80c01b0d2c0e8ced61cc3e5ed179f72ecfa0fc7cf22ae9...
# 1      10479395  cfe86ef0933978bf62fd251f67421b2fb0dad171d17076...
# 2      10479454  eb4c93b800983eb5fdba780b27f6486c83044544bf0b2a...
# 3      10479458  622072008543ccc6ce94a1213b3c1993ddc4a920f7b34a...
# 4      10479469  d0184bde51d229b96acfc69db68e503171dfa0c2743ade...
# ...         ...                                                ...
# 55525  10607351  33dc82f5d7e2facb223e88a102e629700f8ef0f2157f0a...
# 55526  10607352  33dc82f5d7e2facb223e88a102e629700f8ef0f2157f0a...
# 55527  10607353  33dc82f5d7e2facb223e88a102e629700f8ef0f2157f0a...
# 55528  10607361  43abd1d9979173615f736d15305a7df48894d4d81238a4...
# 55529  10607364  198adb7cee4a179c48a896ae776be358cfb45d615c11df...
#
#                                                  account      state  \
# 0      346849be0324afaef1154c59d4aaf3782f4954e891c580...  COMPLETED
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/lookback35_anon_nov1_dec1.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
op_df.to_csv(filepath,index=False)

# %%
df_jul = create_input_data.read_data(csv_file_name="../data/raw/anon_jobs_1July2022_1Aug2022_normal_sorted.csv", parse_dates_col=[4,5,6])
df_jul
# Out:
#           jobid                                               user  \
# 0       9904495  5315c0d39d9b80958306da0d58d4c80f23511dbf320c59...
# 1       9904499  8c8edaea40f116a07e9349440f28d10f95187ac2a5f369...
# 2       9904501  8c8edaea40f116a07e9349440f28d10f95187ac2a5f369...
# 3       9904502  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 4       9904503  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# ...         ...                                                ...
# 67320  10056827  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 67321  10056828  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 67322  10056829  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 67323  10056831  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
# 67324  10056833  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
#
#                                                  account      state  \
# 0      13f12669b2c1d64b36b4333e0df18511fec7136beb13a9...  COMPLETED
# ...

# %%
from importlib import reload
reload(create_input_data)
lookback=35 #rows_discard=34
col_name="queue_minutes"
op_df_jul,rows_to_discard=create_input_data.optimised_add_past_k_obs_insert(lookback, df_jul,col_name)
# Out:
# *** loopback_count never equals to  lookback. so do not consider the row 0
# *** loopback_count never equals to  lookback. so do not consider the row 1
# *** loopback_count never equals to  lookback. so do not consider the row 2
# *** loopback_count never equals to  lookback. so do not consider the row 3
# *** loopback_count never equals to  lookback. so do not consider the row 4
# *** loopback_count never equals to  lookback. so do not consider the row 5
# *** loopback_count never equals to  lookback. so do not consider the row 6
# *** loopback_count never equals to  lookback. so do not consider the row 7
# *** loopback_count never equals to  lookback. so do not consider the row 8
# *** loopback_count never equals to  lookback. so do not consider the row 9
# *** loopback_count never equals to  lookback. so do not consider the row 10
# *** loopback_count never equals to  lookback. so do not consider the row 11
# ...

# %%
op_df_jul
# Out:
#           jobid                                               user  \
# 0       9904495  5315c0d39d9b80958306da0d58d4c80f23511dbf320c59...
# 1       9904499  8c8edaea40f116a07e9349440f28d10f95187ac2a5f369...
# 2       9904501  8c8edaea40f116a07e9349440f28d10f95187ac2a5f369...
# 3       9904502  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 4       9904503  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# ...         ...                                                ...
# 67320  10056827  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 67321  10056828  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 67322  10056829  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 67323  10056831  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
# 67324  10056833  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
#
#                                                  account      state  \
# 0      13f12669b2c1d64b36b4333e0df18511fec7136beb13a9...  COMPLETED
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/lookback35_anon_jul1_aug1.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
op_df_jul.to_csv(filepath,index=False)

# %%
df2 = create_input_data.add_past_k_obs_insert(past_k_obs=10, df=df,col_name="queue_minutes", original_col_off=17,col_obs_off=0)
df2
# Out:
# QM_LEN323216
# c=0
# c=1
# c=2
# c=3
# c=4
# c=5
# c=6
# c=7
# c=8
# c=9
#            jobid                                               user  \
# 0        9084275  5a1c85eb8bc9d4da20ce12b96ecc7bb9d79d3ef991e990...
# 1        9084279  b4b4df9343fe9f7110ec15863fb5df13fbd20268383ba9...
# 2        9084280  c593da51b38e5fd95cb891ec53a4b70c41ca189bf4b92d...
# 3        9084291  db3b1cee65585e6744e72478a737eafaa23ce99e81344e...
# 4        9084294  bb3cdc72e4a6895d67d00ccd3c9cf0f65bdc59f32dfa9e...
# ...          ...                                                ...
# 323211  10056827  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323212  10056828  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323213  10056829  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323214  10056831  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
# 323215  10056833  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
#
#                                                   account      state  \
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/anon_past_10_completed_qm.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
df2.to_csv(filepath,index=False)

# %%
df3 = create_input_data.add_past_k_obs_insert(past_k_obs=25, df=df,col_name="queue_minutes", original_col_off=17,col_obs_off=10)
df3
# Out:
# QM_LEN323216
# c=10
# c=11
# c=12
# c=13
# c=14
# c=15
# c=16
# c=17
# c=18
# c=19
# c=20
# c=21
# c=22
# c=23
# c=24
#            jobid                                               user  \
# 0        9084275  5a1c85eb8bc9d4da20ce12b96ecc7bb9d79d3ef991e990...
# 1        9084279  b4b4df9343fe9f7110ec15863fb5df13fbd20268383ba9...
# 2        9084280  c593da51b38e5fd95cb891ec53a4b70c41ca189bf4b92d...
# 3        9084291  db3b1cee65585e6744e72478a737eafaa23ce99e81344e...
# 4        9084294  bb3cdc72e4a6895d67d00ccd3c9cf0f65bdc59f32dfa9e...
# ...          ...                                                ...
# 323211  10056827  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323212  10056828  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323213  10056829  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323214  10056831  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
# 323215  10056833  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
#
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/anon_past_25_completed_qm.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
df3.to_csv(filepath,index=False)

# %%
df4 = create_input_data.add_past_k_obs_insert(past_k_obs=35, df=df,col_name="queue_minutes", original_col_off=17,col_obs_off=25)
df4
# Out:
# QM_LEN323216
# c=25
# c=26
# c=27
# c=28
# c=29
# c=30
# c=31
# c=32
# c=33
# c=34
#            jobid                                               user  \
# 0        9084275  5a1c85eb8bc9d4da20ce12b96ecc7bb9d79d3ef991e990...
# 1        9084279  b4b4df9343fe9f7110ec15863fb5df13fbd20268383ba9...
# 2        9084280  c593da51b38e5fd95cb891ec53a4b70c41ca189bf4b92d...
# 3        9084291  db3b1cee65585e6744e72478a737eafaa23ce99e81344e...
# 4        9084294  bb3cdc72e4a6895d67d00ccd3c9cf0f65bdc59f32dfa9e...
# ...          ...                                                ...
# 323211  10056827  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323212  10056828  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323213  10056829  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323214  10056831  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
# 323215  10056833  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
#
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/anon_past_35_completed_qm.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
df3.to_csv(filepath,index=False)

# %%
df5 = create_input_data.add_past_k_obs_insert(past_k_obs=50, df=df,col_name="queue_minutes", original_col_off=17,col_obs_off=35)
df5
# Out:
# QM_LEN323216
# c=35
# c=36
# c=37
# c=38
# c=39
# c=40
# c=41
# c=42
# c=43
# c=44
# c=45
# c=46
# c=47
# c=48
# c=49
#            jobid                                               user  \
# 0        9084275  5a1c85eb8bc9d4da20ce12b96ecc7bb9d79d3ef991e990...
# 1        9084279  b4b4df9343fe9f7110ec15863fb5df13fbd20268383ba9...
# 2        9084280  c593da51b38e5fd95cb891ec53a4b70c41ca189bf4b92d...
# 3        9084291  db3b1cee65585e6744e72478a737eafaa23ce99e81344e...
# 4        9084294  bb3cdc72e4a6895d67d00ccd3c9cf0f65bdc59f32dfa9e...
# ...          ...                                                ...
# 323211  10056827  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323212  10056828  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323213  10056829  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323214  10056831  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
# 323215  10056833  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
#
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/anon_past_50_completed_qm.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
df5.to_csv(filepath,index=False)

# %%
df6 = create_input_data.add_past_k_obs_insert(past_k_obs=75, df=df,col_name="queue_minutes", original_col_off=17,col_obs_off=50)
df6
# Out:
# QM_LEN323216
# c=50
# c=51
# c=52
# c=53
# c=54
# c=55
# c=56
# c=57
# c=58
# c=59
# c=60
# c=61
# c=62
# c=63
# c=64
# c=65
# c=66
# c=67
# c=68
# c=69
# c=70
# c=71
# c=72
# c=73
# c=74
#            jobid                                               user  \
# 0        9084275  5a1c85eb8bc9d4da20ce12b96ecc7bb9d79d3ef991e990...
# 1        9084279  b4b4df9343fe9f7110ec15863fb5df13fbd20268383ba9...
# 2        9084280  c593da51b38e5fd95cb891ec53a4b70c41ca189bf4b92d...
# 3        9084291  db3b1cee65585e6744e72478a737eafaa23ce99e81344e...
# 4        9084294  bb3cdc72e4a6895d67d00ccd3c9cf0f65bdc59f32dfa9e...
# ...          ...                                                ...
# 323211  10056827  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323212  10056828  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323213  10056829  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323214  10056831  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/anon_past_75_completed_qm.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
df6.to_csv(filepath,index=False)

# %%
df6 = create_input_data.add_past_k_obs_insert(past_k_obs=100, df=df,col_name="queue_minutes", original_col_off=17,col_obs_off=75)
df6
# Out:
# QM_LEN323216
# c=75
# c=76
# c=77
# c=78
# c=79
# c=80
# c=81
# c=82
# c=83
# c=84
# c=85
# c=86
# c=87
# c=88
# c=89
# c=90
# c=91
# c=92
# c=93
# c=94
# c=95
# c=96
# c=97
# /home/jovyan/work/src/data/create_input_data.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(COLUMN_OFFSET+c,name,new)
# c=98
# /home/jovyan/work/src/data/create_input_data.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(COLUMN_OFFSET+c,name,new)
# c=99
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/anon_past_100_completed_qm.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
df6.to_csv(filepath,index=False)

# %%
import sys
sys.path.append('/home/jovyan/work/')
sys.path.append('/home/jovyan/work/src')
sys.path.append('/home/jovyan/work/src/data')
sys.path.append('/home/jovyan/work/src/data_explore')
sys.path.append('/home/jovyan/work/src/features')
sys.path.append('/home/jovyan/work/src/models')
sys.path.append('/home/jovyan/work/src/analysis')

# %%
from src import data,data_explore,features
from data import create_input_data
from data_explore import explore_util
from features import build_features
from models import train_model,predict_model
from analysis import analyze_pred

# %%
#df_aug = create_input_data.read_data(csv_file_name="../data/raw/anon_jobs_1Aug2022_1Sept2022normal_sorted.csv", parse_dates_col=[4,5,6])
df_aug = create_input_data.read_data(csv_file_name="../data/raw/anon_jobs_1Feb2022_1Aug2022_normal_sorted.csv", parse_dates_col=[4,5,6])
df_aug
# Out:
#            jobid                                               user  \
# 0        9084275  5a1c85eb8bc9d4da20ce12b96ecc7bb9d79d3ef991e990...
# 1        9084279  b4b4df9343fe9f7110ec15863fb5df13fbd20268383ba9...
# 2        9084280  c593da51b38e5fd95cb891ec53a4b70c41ca189bf4b92d...
# 3        9084291  db3b1cee65585e6744e72478a737eafaa23ce99e81344e...
# 4        9084294  bb3cdc72e4a6895d67d00ccd3c9cf0f65bdc59f32dfa9e...
# ...          ...                                                ...
# 323211  10056827  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323212  10056828  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323213  10056829  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323214  10056831  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
# 323215  10056833  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
#
#                                                   account      state  \
# 0       38112a802292edea407a0678c9c75259cba6473c7acc62...  COMPLETED
# ...

# %%
reload(create_input_data)
reload(build_features)
#df_aug=build_features.slice_df(df_aug,0,2000)
#col_names=['user','account','state','reqcpus','nnodes','max_minutes','backlog_minutes','running_num_jobs','running_minutes','backlog_num_jobs','run_minutes','nodelist']
#df_aug=build_features.remove_cols(df_aug, col_names)
# Out:
# <module 'features.build_features' from '/home/jovyan/work/src/features/build_features.py'>

# %%
df_aug
# Out:
#            jobid                                               user  \
# 0        9084275  5a1c85eb8bc9d4da20ce12b96ecc7bb9d79d3ef991e990...
# 1        9084279  b4b4df9343fe9f7110ec15863fb5df13fbd20268383ba9...
# 2        9084280  c593da51b38e5fd95cb891ec53a4b70c41ca189bf4b92d...
# 3        9084291  db3b1cee65585e6744e72478a737eafaa23ce99e81344e...
# 4        9084294  bb3cdc72e4a6895d67d00ccd3c9cf0f65bdc59f32dfa9e...
# ...          ...                                                ...
# 323211  10056827  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323212  10056828  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323213  10056829  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323214  10056831  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
# 323215  10056833  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
#
#                                                   account      state  \
# 0       38112a802292edea407a0678c9c75259cba6473c7acc62...  COMPLETED
# ...

# %%
reload(create_input_data)
df1 = create_input_data.add_past_k_obs_insert(past_k_obs=10, df=df_aug,col_name="queue_minutes", original_col_off=17,col_obs_off=0)
df1
# Out:
# QM_LEN323216
# ------ column c=0
# ------ column c=1
# ------ column c=2
# ------ column c=3
# ------ column c=4
# ------ column c=5
# ------ column c=6
# ------ column c=7
# ------ column c=8
# ------ column c=9
#            jobid                                               user  \
# 0        9084275  5a1c85eb8bc9d4da20ce12b96ecc7bb9d79d3ef991e990...
# 1        9084279  b4b4df9343fe9f7110ec15863fb5df13fbd20268383ba9...
# 2        9084280  c593da51b38e5fd95cb891ec53a4b70c41ca189bf4b92d...
# 3        9084291  db3b1cee65585e6744e72478a737eafaa23ce99e81344e...
# 4        9084294  bb3cdc72e4a6895d67d00ccd3c9cf0f65bdc59f32dfa9e...
# ...          ...                                                ...
# 323211  10056827  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323212  10056828  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323213  10056829  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323214  10056831  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/correct_anon_past_10_completed_qm.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
df1.to_csv(filepath,index=False)

# %%
from importlib import reload
reload(create_input_data)
create_input_data.add_past_k_obs_insert(past_k_obs=25, df=df1,col_name="queue_minutes", original_col_off=17,col_obs_off=10)
# Out:
# QM_LEN323216
# ------ column c=10
# ------ column c=11
# ------ column c=12
# ------ column c=13
# ------ column c=14
# ------ column c=15
# ------ column c=16
# ------ column c=17
# ------ column c=18
# ------ column c=19
# ------ column c=20
#  start time at row (i): 32061  submit time at row (r): 32168
# start: 2022-02-25 14:03:35
# submit: 2022-02-25 14:04:46
# count_pbs: 21
# queue minute added: 452
# ------ column c=21
#  start time at row (i): 32060  submit time at row (r): 32168
# start: 2022-02-25 14:03:01
# submit: 2022-02-25 14:04:46
# count_pbs: 22
# queue minute added: 452
#  start time at row (i): 32061  submit time at row (r): 32169
# start: 2022-02-25 14:03:35
# submit: 2022-02-25 14:06:29
# count_pbs: 22
# queue minute added: 452
#  start time at row (i): 32061  submit time at row (r): 32170
# start: 2022-02-25 14:03:35
# submit: 2022-02-25 14:16:46
# count_pbs: 22
# queue minute added: 452
# ------ column c=22
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/correct_anon_past_25_completed_qm.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
df1.to_csv(filepath,index=False)

# %%
df1
# Out:
#            jobid                                               user  \
# 0        9084275  5a1c85eb8bc9d4da20ce12b96ecc7bb9d79d3ef991e990...
# 1        9084279  b4b4df9343fe9f7110ec15863fb5df13fbd20268383ba9...
# 2        9084280  c593da51b38e5fd95cb891ec53a4b70c41ca189bf4b92d...
# 3        9084291  db3b1cee65585e6744e72478a737eafaa23ce99e81344e...
# 4        9084294  bb3cdc72e4a6895d67d00ccd3c9cf0f65bdc59f32dfa9e...
# ...          ...                                                ...
# 323211  10056827  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323212  10056828  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323213  10056829  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323214  10056831  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
# 323215  10056833  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
#
#                                                   account      state  \
# 0       38112a802292edea407a0678c9c75259cba6473c7acc62...  COMPLETED
# ...

# %%
df2=create_input_data.add_past_k_obs_insert(past_k_obs=35, df=df1,col_name="queue_minutes", original_col_off=17,col_obs_off=25)
# Out:
# QM_LEN323216
# ------ column c=25
#  start time at row (i): 41291  submit time at row (r): 41403
# start: 2022-03-05 14:24:01
# submit: 2022-03-05 14:26:26
# count_pbs: 26
# queue minute added: 452
# ------ column c=26
#  start time at row (i): 37140  submit time at row (r): 37210
# start: 2022-03-02 10:35:42
# submit: 2022-03-02 11:25:58
# count_pbs: 27
# queue minute added: 452
#  start time at row (i): 37140  submit time at row (r): 37211
# start: 2022-03-02 10:35:42
# submit: 2022-03-02 11:26:14
# count_pbs: 27
# queue minute added: 452
#  start time at row (i): 37140  submit time at row (r): 37212
# start: 2022-03-02 10:35:42
# submit: 2022-03-02 11:26:25
# count_pbs: 27
# queue minute added: 452
# ------ column c=27
# ------ column c=28
#  start time at row (i): 41291  submit time at row (r): 41404
# start: 2022-03-05 14:24:01
# submit: 2022-03-05 14:34:35
# count_pbs: 29
# queue minute added: 452
#  start time at row (i): 56962  submit time at row (r): 57195
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/correct_anon_past_35_completed_qm.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
df2.to_csv(filepath,index=False)

# %%
df = create_input_data.read_data(csv_file_name="../data/processed/correct_anon_past_35_completed_qm.csv", parse_dates_col=[4,5,6])
df3=create_input_data.add_past_k_obs_insert(past_k_obs=50, df=df,col_name="queue_minutes", original_col_off=17,col_obs_off=35)
df3
# Out:
# QM_LEN323216
# ------ column c=35
#  start time at row (i): 37140  submit time at row (r): 37261
# start: 2022-03-02 10:35:42
# submit: 2022-03-02 11:47:21
# count_pbs: 36
# queue minute added: 452
# ------ column c=36
# ------ column c=37
# ------ column c=38
#  start time at row (i): 32061  submit time at row (r): 32177
# start: 2022-02-25 14:03:35
# submit: 2022-02-25 14:40:30
# count_pbs: 39
# queue minute added: 452
# ------ column c=39
#  start time at row (i): 32060  submit time at row (r): 32177
# start: 2022-02-25 14:03:01
# submit: 2022-02-25 14:40:30
# count_pbs: 40
# queue minute added: 452
# ------ column c=40
# ------ column c=41
#  start time at row (i): 37140  submit time at row (r): 37262
# start: 2022-03-02 10:35:42
# submit: 2022-03-02 12:01:41
# count_pbs: 42
# queue minute added: 452
# ------ column c=42
# ------ column c=43
# ------ column c=44
#  start time at row (i): 32061  submit time at row (r): 32178
# start: 2022-02-25 14:03:35
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/correct_anon_past_50_completed_qm.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
df3.to_csv(filepath,index=False)

# %%
df_sept = create_input_data.read_data(csv_file_name="../data/raw/anon_jobs_1Aug2022_1Sept2022normal_sorted.csv", parse_dates_col=[4,5,6])
#df_aug = create_input_data.read_data(csv_file_name="../data/raw/anon_jobs_1Feb2022_1Aug2022_normal_sorted.csv", parse_dates_col=[4,5,6])
df_sept
# Out:
#           jobid                                               user  \
# 0      10056839  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 1      10056840  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 2      10056841  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 3      10056842  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 4      10056843  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# ...         ...                                                ...
# 69796  10202512  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69797  10202513  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69798  10202514  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69799  10202515  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69800  10202518  1de6066a413cc648a42769513f6172d497ca612c3e6c7a...
#
#                                                  account      state  \
# 0      fa2629c2b0c98b9f3d8366895b45442f1f33b51ef9f075...  COMPLETED
# ...

# %%
df_new_sept=create_input_data.add_past_k_obs_insert(past_k_obs=25, df=df_sept,col_name="queue_minutes", original_col_off=17,col_obs_off=0)
df_new_sept
# Out:
# QM_LEN69801
# ------ column c=0
# ------ column c=1
# ------ column c=2
# ------ column c=3
# ------ column c=4
# ------ column c=5
# ------ column c=6
# ------ column c=7
# ------ column c=8
# ------ column c=9
# ------ column c=10
# ------ column c=11
# ------ column c=12
# ------ column c=13
# ------ column c=14
# ------ column c=15
# ------ column c=16
# ------ column c=17
# ------ column c=18
# ------ column c=19
# ------ column c=20
# ------ column c=21
# ------ column c=22
# ------ column c=23
# ------ column c=24
#           jobid                                               user  \
# 0      10056839  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 1      10056840  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 2      10056841  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 3      10056842  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 4      10056843  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/correct_anon_aug_sept_past2022_25_completed_qm.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
df_new_sept.to_csv(filepath,index=False)

# %%
df_new_aug=create_input_data.add_past_k_obs_insert(past_k_obs=35, df=df_aug,col_name="queue_minutes", original_col_off=17,col_obs_off=0)
df_new_aug
# Out:
# QM_LEN69801
# ------ column c=0
# ------ column c=1
# ------ column c=2
# ------ column c=3
# ------ column c=4
# ------ column c=5
# ------ column c=6
# ------ column c=7
# ------ column c=8
# ------ column c=9
# ------ column c=10
# ------ column c=11
# ------ column c=12
# ------ column c=13
# ------ column c=14
# ------ column c=15
# ------ column c=16
# ------ column c=17
# ------ column c=18
# ------ column c=19
# ------ column c=20
# ------ column c=21
# ------ column c=22
# ------ column c=23
# ------ column c=24
# ------ column c=25
# ------ column c=26
# ------ column c=27
# ------ column c=28
# ------ column c=29
# ------ column c=30
# ------ column c=31
# ------ column c=32
# ------ column c=33
# ------ column c=34
#           jobid                                               user  \
# 0      10056839  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 1      10056840  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/correct_anon_aug_sept_past2022_35_completed_qm.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
df_new_aug.to_csv(filepath,index=False)

# %%
df_new_aug
# Out:
#           jobid                                               user  \
# 0      10056839  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 1      10056840  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 2      10056841  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 3      10056842  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 4      10056843  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# ...         ...                                                ...
# 69796  10202512  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69797  10202513  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69798  10202514  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69799  10202515  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69800  10202518  1de6066a413cc648a42769513f6172d497ca612c3e6c7a...
#
#                                                  account      state  \
# 0      fa2629c2b0c98b9f3d8366895b45442f1f33b51ef9f075...  COMPLETED
# ...

# %%
df_aug
# Out:
#           jobid                                               user  \
# 0      10056839  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 1      10056840  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 2      10056841  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 3      10056842  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 4      10056843  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# ...         ...                                                ...
# 69796  10202512  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69797  10202513  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69798  10202514  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69799  10202515  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69800  10202518  1de6066a413cc648a42769513f6172d497ca612c3e6c7a...
#
#                                                  account      state  \
# 0      fa2629c2b0c98b9f3d8366895b45442f1f33b51ef9f075...  COMPLETED
# ...

# %%
df_aug
# Out:
#           jobid                                               user  \
# 0      10056839  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 1      10056840  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 2      10056841  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 3      10056842  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 4      10056843  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# ...         ...                                                ...
# 69796  10202512  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69797  10202513  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69798  10202514  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69799  10202515  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69800  10202518  1de6066a413cc648a42769513f6172d497ca612c3e6c7a...
#
#                                                  account      state  \
# 0      fa2629c2b0c98b9f3d8366895b45442f1f33b51ef9f075...  COMPLETED
# ...

# %%
df_aug
# Out:
#           jobid                                               user  \
# 0      10056839  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 1      10056840  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 2      10056841  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 3      10056842  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 4      10056843  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# ...         ...                                                ...
# 69796  10202512  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69797  10202513  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69798  10202514  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69799  10202515  350d51d0ac5acfacc4539962a6f1f3e3516dcc7f6d0bee...
# 69800  10202518  1de6066a413cc648a42769513f6172d497ca612c3e6c7a...
#
#                                                  account      state  \
# 0      fa2629c2b0c98b9f3d8366895b45442f1f33b51ef9f075...  COMPLETED
# ...

# %%
df.shape[0]
# Out:
# 323216

# %%
cnames = list(df)[0:5]
cnames
# Out:
# ['jobid', 'user', 'account', 'state', 'submit']

# %%
lookbacklist=[]
for i in range(0,len(cnames)):
    lookbacklist.append([])

# %%
lookbacklist
# Out:
# [[], [], [], [], []]

# %%
for i in range(0,5):
    for k in range(0, len(cnames)):
        lookbacklist[k].append(df.at[i, cnames[k]])
lookbacklist
# Out:
# [[9084275, 9084279, 9084280, 9084291, 9084294],
#  ['5a1c85eb8bc9d4da20ce12b96ecc7bb9d79d3ef991e990f3626d7f50a5dfef6e',
#   'b4b4df9343fe9f7110ec15863fb5df13fbd20268383ba9b184a9489802712f1f',
#   'c593da51b38e5fd95cb891ec53a4b70c41ca189bf4b92d2632ac7f79efd9f751',
#   'db3b1cee65585e6744e72478a737eafaa23ce99e81344e701e7fa26a3cf05926',
#   'bb3cdc72e4a6895d67d00ccd3c9cf0f65bdc59f32dfa9ee2128b6084cbbc4ef7'],
#  ['38112a802292edea407a0678c9c75259cba6473c7acc62aba1370f7222d12c01',
#   '9490a70089cec5b24a43f5f535efc92180fc5383256414fe438e91d932b34753',
#   '3a61323a47592f74d9ca0004a066b2019b8fc1d4c53283eca08f087df9e97dab',
#   '118341ad5b87466ce69926005d0d6ba762bf86b8996da75c6c360ca40a29fbdb',
#   '664af438b9c1ef9ba68a8105b0ce50f87b8bc4624860439b82e620a7eb6923a0'],
#  ['COMPLETED', 'COMPLETED', 'COMPLETED', 'COMPLETED', 'COMPLETED'],
#  [Timestamp('2022-02-01 00:10:00'),
#   Timestamp('2022-02-01 00:11:44'),
#   Timestamp('2022-02-01 00:12:27'),
#   Timestamp('2022-02-01 00:16:45'),
# ...

# %%
sub_df=df.iloc[0:10,0:15]

# %%
sub_df
# Out:
#      jobid                                               user  \
# 0  9084275  5a1c85eb8bc9d4da20ce12b96ecc7bb9d79d3ef991e990...
# 1  9084279  b4b4df9343fe9f7110ec15863fb5df13fbd20268383ba9...
# 2  9084280  c593da51b38e5fd95cb891ec53a4b70c41ca189bf4b92d...
# 3  9084291  db3b1cee65585e6744e72478a737eafaa23ce99e81344e...
# 4  9084294  bb3cdc72e4a6895d67d00ccd3c9cf0f65bdc59f32dfa9e...
# 5  9084304  1e28cab4a3a687f56bb0f3b2f8dc0f45bcbdeb49fdfbce...
# 6  9084324  e5c772ae3fbea0da64f9bdeb5f3281c86d86a2e6e9fc2e...
# 7  9084332  db3b1cee65585e6744e72478a737eafaa23ce99e81344e...
# 8  9084347  b4b4df9343fe9f7110ec15863fb5df13fbd20268383ba9...
# 9  9084355  9d1f4707e26788bd39631e292f7ee43181226069fd6d8f...
#
#                                              account      state  \
# 0  38112a802292edea407a0678c9c75259cba6473c7acc62...  COMPLETED
# 1  9490a70089cec5b24a43f5f535efc92180fc5383256414...  COMPLETED
# 2  3a61323a47592f74d9ca0004a066b2019b8fc1d4c53283...  COMPLETED
# ...

# %%
sub_df = build_features.remove_cols(sub_df,['jobid','user','account','state'])

# %%
sub_df
# Out:
#                submit               start                 end  reqcpus  \
# 0 2022-02-01 00:10:00 2022-02-01 00:10:02 2022-02-01 18:10:39        1
# 1 2022-02-01 00:11:44 2022-02-01 07:44:39 2022-02-01 09:00:46       78
# 2 2022-02-01 00:12:27 2022-02-01 00:12:27 2022-02-01 00:12:39       68
# 3 2022-02-01 00:16:45 2022-02-01 04:43:31 2022-02-01 06:15:04       64
# 4 2022-02-01 00:17:49 2022-02-01 00:17:51 2022-02-01 00:58:55       64
# 5 2022-02-01 00:18:35 2022-02-01 00:18:36 2022-02-01 01:13:43       16
# 6 2022-02-01 00:20:34 2022-02-01 00:20:34 2022-02-01 01:51:34       16
# 7 2022-02-01 00:23:46 2022-02-01 04:55:24 2022-02-01 06:26:53       64
# 8 2022-02-01 00:31:31 2022-02-01 07:45:05 2022-02-01 10:53:40       78
# 9 2022-02-01 00:33:19 2022-02-01 00:33:21 2022-02-01 00:35:07        1
#
#    nnodes  max_minutes  queue_minutes  backlog_minutes  backlog_num_jobs  \
# 0       1         2880              0           131060               143
# ...

# %%
from importlib import reload
reload(create_input_data)
lookback = 1
lstm_input, rows_to_discard = create_input_data.input_data_lstm(lookback, sub_df)
# Out:
# ---- submit: 2022-02-01 00:11:44  row = 1
# start: 2022-02-01 00:10:02
# getting the column name:reqcpus value=1
# getting the column name:nnodes value=1
# getting the column name:max_minutes value=2880
# getting the column name:queue_minutes value=0
# getting the column name:backlog_minutes value=131060
# getting the column name:backlog_num_jobs value=143
# getting the column name:running_num_jobs value=20382
# getting the column name:running_minutes value=7955377
# count_lookback equals to lookback at row: 0
# ---- submit: 2022-02-01 00:12:27  row = 2
# start: 2022-02-01 00:10:02
# getting the column name:reqcpus value=1
# getting the column name:nnodes value=1
# getting the column name:max_minutes value=2880
# getting the column name:queue_minutes value=0
# getting the column name:backlog_minutes value=131060
# getting the column name:backlog_num_jobs value=143
# getting the column name:running_num_jobs value=20382
# getting the column name:running_minutes value=7955377
# ...

# %%
rows_to_discard
# Out:
# 0

# %%
import numpy as np
lstm_array = np.array(lstm_input)
lstm_array.shape
# Out:
# (9, 8, 1)

# %%
lstm_array
# Out:
# array([[[      1],
#         [      1],
#         [   2880],
#         [      0],
#         [ 131060],
#         [    143],
#         [  20382],
#         [7955377]],
#
#        [[      1],
#         [      1],
#         [   2880],
#         [      0],
#         [ 131060],
#         [    143],
#         [  20382],
#         [7955377]],
#
#        [[     68],
#         [      1],
#         [      1],
#         [      0],
#         [ 131240],
#         [    144],
#         [  20382],
#         [7955377]],
#
#        [[     68],
#         [      1],
#         [      1],
#         [      0],
#         [ 131240],
#         [    144],
#         [  20382],
#         [7955377]],
#
#        [[     64],
#         [      1],
#         [     58],
#         [      0],
#         [ 133980],
#         [    143],
#         [  20383],
#         [7955378]],
#
#        [[     16],
#         [      1],
#         [   2880],
#         [      0],
#         [ 133980],
#         [    143],
# ...

# %%
lstm_array[0]
# Out:
# array([[      1],
#        [      1],
#        [   2880],
#        [      0],
#        [ 131060],
#        [    143],
#        [  20382],
#        [7955377]])

# %%
x=lstm_array[0]
x
# Out:
# array([[      1],
#        [      1],
#        [   2880],
#        [      0],
#        [ 131060],
#        [    143],
#        [  20382],
#        [7955377]])

# %%
lstm_array[0].shape
# Out:
# (8, 1)

# %%
lstm_array[0].T.shape
# Out:
# (1, 8)

# %%
lstm_array[0].T
# Out:
# array([[      1,       1,    2880,       0,  131060,     143,   20382,
#         7955377]])

# %%
y = np.swapaxes(x,0,1)

# %%
y.shape
# Out:
# (1, 8)

# %%
transformed_lstm = np.swapaxes(lstm_array,1,2)
transformed_lstm
# Out:
# array([[[      1,       1,    2880,       0,  131060,     143,   20382,
#          7955377]],
#
#        [[      1,       1,    2880,       0,  131060,     143,   20382,
#          7955377]],
#
#        [[     68,       1,       1,       0,  131240,     144,   20382,
#          7955377]],
#
#        [[     68,       1,       1,       0,  131240,     144,   20382,
#          7955377]],
#
#        [[     64,       1,      58,       0,  133980,     143,   20383,
#          7955378]],
#
#        [[     16,       1,    2880,       0,  133980,     143,   20383,
#          7955378]],
#
#        [[     16,       1,     330,       0,  133910,     142,   20383,
#          7955378]],
#
#        [[     16,       1,     330,       0,  133910,     142,   20383,
#          7955378]],
#
#        [[     16,       1,     330,       0,  133910,     142,   20383,
#          7955378]]])

# %%
transformed_lstm.shape
# Out:
# (9, 1, 8)

# %%
from importlib import reload
reload(create_input_data)
lookback = 2
lstm_input2, rows_to_discard = create_input_data.input_data_lstm(lookback, sub_df)
# Out:
# ---- submit: 2022-02-01 00:12:27  row = 2
# start: 2022-02-01 00:10:02
# getting the column name:reqcpus value=1
# getting the column name:nnodes value=1
# getting the column name:max_minutes value=2880
# getting the column name:queue_minutes value=0
# getting the column name:backlog_minutes value=131060
# getting the column name:backlog_num_jobs value=143
# getting the column name:running_num_jobs value=20382
# getting the column name:running_minutes value=7955377
# loopback count never equals to  lookback. so do not consider the row 2
# ---- submit: 2022-02-01 00:16:45  row = 3
# start: 2022-02-01 00:12:27
# getting the column name:reqcpus value=68
# getting the column name:nnodes value=1
# getting the column name:max_minutes value=1
# getting the column name:queue_minutes value=0
# getting the column name:backlog_minutes value=131240
# getting the column name:backlog_num_jobs value=144
# getting the column name:running_num_jobs value=20382
# ...

# %%
lstm_input2_arr = np.array(lstm_input2)
lstm_input2_arr.shape
# Out:
# (7, 8, 2)

# %%
rows_to_discard
# Out:
# 2

# %%
lstm_input2_arr
# Out:
# array([[[     68,       1],
#         [      1,       1],
#         [      1,    2880],
#         [      0,       0],
#         [ 131240,  131060],
#         [    144,     143],
#         [  20382,   20382],
#         [7955377, 7955377]],
#
#        [[     68,       1],
#         [      1,       1],
#         [      1,    2880],
#         [      0,       0],
#         [ 131240,  131060],
#         [    144,     143],
#         [  20382,   20382],
#         [7955377, 7955377]],
#
#        [[     64,      68],
#         [      1,       1],
#         [     58,       1],
#         [      0,       0],
#         [ 133980,  131240],
#         [    143,     144],
#         [  20383,   20382],
#         [7955378, 7955377]],
#
#        [[     16,      64],
#         [      1,       1],
#         [   2880,      58],
#         [      0,       0],
#         [ 133980,  133980],
#         [    143,     143],
#         [  20383,   20383],
#         [7955378, 7955378]],
#
# ...

# %%
transformed_lstm_2 = np.swapaxes(lstm_input2_arr,1,2)
transformed_lstm_2
# Out:
# array([[[     68,       1,       1,       0,  131240,     144,   20382,
#          7955377],
#         [      1,       1,    2880,       0,  131060,     143,   20382,
#          7955377]],
#
#        [[     68,       1,       1,       0,  131240,     144,   20382,
#          7955377],
#         [      1,       1,    2880,       0,  131060,     143,   20382,
#          7955377]],
#
#        [[     64,       1,      58,       0,  133980,     143,   20383,
#          7955378],
#         [     68,       1,       1,       0,  131240,     144,   20382,
#          7955377]],
#
#        [[     16,       1,    2880,       0,  133980,     143,   20383,
#          7955378],
#         [     64,       1,      58,       0,  133980,     143,   20383,
#          7955378]],
#
#        [[     16,       1,     330,       0,  133910,     142,   20383,
#          7955378],
#         [     16,       1,    2880,       0,  133980,     143,   20383,
#          7955378]],
#
# ...

# %%
transformed_lstm_2.shape
# Out:
# (7, 2, 8)

# %%
from importlib import reload
reload(create_input_data)
lookback = 3
lstm_input3, rows_to_discard = create_input_data.input_data_lstm(lookback, sub_df)
# Out:
# ---- submit: 2022-02-01 00:16:45  row = 3
# start: 2022-02-01 00:12:27
# start: 2022-02-01 00:10:02
# *** loopback count never equals to  lookback. so do not consider the row 3
# ---- submit: 2022-02-01 00:17:49  row = 4
# start: 2022-02-01 00:12:27
# start: 2022-02-01 00:10:02
# *** loopback count never equals to  lookback. so do not consider the row 4
# ---- submit: 2022-02-01 00:18:35  row = 5
# start: 2022-02-01 00:17:51
# start: 2022-02-01 00:12:27
# start: 2022-02-01 00:10:02
# count_lookback equals to lookback at row: 0
# ---- submit: 2022-02-01 00:20:34  row = 6
# start: 2022-02-01 00:18:36
# start: 2022-02-01 00:17:51
# start: 2022-02-01 00:12:27
# count_lookback equals to lookback at row: 2
# ---- submit: 2022-02-01 00:23:46  row = 7
# start: 2022-02-01 00:20:34
# start: 2022-02-01 00:18:36
# start: 2022-02-01 00:17:51
# count_lookback equals to lookback at row: 4
# ---- submit: 2022-02-01 00:31:31  row = 8
# start: 2022-02-01 00:20:34
# start: 2022-02-01 00:18:36
# ...

# %%
rows_to_discard
# Out:
# 4

# %%
lstm_input3
# Out:
# array([[[     64,       1,      58,       0,  133980,     143,   20383,
#          7955378],
#         [     68,       1,       1,       0,  131240,     144,   20382,
#          7955377],
#         [      1,       1,    2880,       0,  131060,     143,   20382,
#          7955377]],
#
#        [[     16,       1,    2880,       0,  133980,     143,   20383,
#          7955378],
#         [     64,       1,      58,       0,  133980,     143,   20383,
#          7955378],
#         [     68,       1,       1,       0,  131240,     144,   20382,
#          7955377]],
#
#        [[     16,       1,     330,       0,  133910,     142,   20383,
#          7955378],
#         [     16,       1,    2880,       0,  133980,     143,   20383,
#          7955378],
#         [     64,       1,      58,       0,  133980,     143,   20383,
#          7955378]],
#
#        [[     16,       1,     330,       0,  133910,     142,   20383,
#          7955378],
# ...

# %%
lstm_input3.shape
# Out:
# (5, 3, 8)

# %%
lookback = 4
lstm_input4, rows_to_discard = create_input_data.input_data_lstm(lookback, sub_df)
# Out:
# ---- submit: 2022-02-01 00:17:49  row = 4
# start: 2022-02-01 00:12:27
# start: 2022-02-01 00:10:02
# *** loopback count never equals to  lookback. so do not consider the row 4
# ---- submit: 2022-02-01 00:18:35  row = 5
# start: 2022-02-01 00:17:51
# start: 2022-02-01 00:12:27
# start: 2022-02-01 00:10:02
# *** loopback count never equals to  lookback. so do not consider the row 5
# ---- submit: 2022-02-01 00:20:34  row = 6
# start: 2022-02-01 00:18:36
# start: 2022-02-01 00:17:51
# start: 2022-02-01 00:12:27
# start: 2022-02-01 00:10:02
# count_lookback equals to lookback at row: 0
# ---- submit: 2022-02-01 00:23:46  row = 7
# start: 2022-02-01 00:20:34
# start: 2022-02-01 00:18:36
# start: 2022-02-01 00:17:51
# start: 2022-02-01 00:12:27
# count_lookback equals to lookback at row: 2
# ---- submit: 2022-02-01 00:31:31  row = 8
# start: 2022-02-01 00:20:34
# start: 2022-02-01 00:18:36
# start: 2022-02-01 00:17:51
# start: 2022-02-01 00:12:27
# ...

# %%
lstm_input4.shape
# Out:
# (4, 4, 8)

# %%
rows_to_discard
# Out:
# 5

# %%
from importlib import reload
reload(create_input_data)
lookback = 5
lstm_input5, rows_to_discard5 = create_input_data.input_data_lstm(lookback, sub_df)
# Out:
# *** loopback count never equals to  lookback. so do not consider the row 5
# *** loopback count never equals to  lookback. so do not consider the row 6

# %%
lstm_input5.shape
# Out:
# (3, 5, 8)

# %%
df.shape
# Out:
# (323216, 67)

# %%
df = create_input_data.read_data(csv_file_name="../data/raw/anon_jobs_1Feb2022_1Aug2022_normal_sorted.csv", parse_dates_col=[4,5,6])
df
# Out:
#            jobid                                               user  \
# 0        9084275  5a1c85eb8bc9d4da20ce12b96ecc7bb9d79d3ef991e990...
# 1        9084279  b4b4df9343fe9f7110ec15863fb5df13fbd20268383ba9...
# 2        9084280  c593da51b38e5fd95cb891ec53a4b70c41ca189bf4b92d...
# 3        9084291  db3b1cee65585e6744e72478a737eafaa23ce99e81344e...
# 4        9084294  bb3cdc72e4a6895d67d00ccd3c9cf0f65bdc59f32dfa9e...
# ...          ...                                                ...
# 323211  10056827  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323212  10056828  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323213  10056829  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323214  10056831  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
# 323215  10056833  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
#
#                                                   account      state  \
# 0       38112a802292edea407a0678c9c75259cba6473c7acc62...  COMPLETED
# ...

# %%
lstm_df = build_features.remove_cols(df,['jobid','user','account','state','run_minutes','nodelist'])

# %%
lstm_df
# Out:
#                     submit               start                 end  reqcpus  \
# 0      2022-02-01 00:10:00 2022-02-01 00:10:02 2022-02-01 18:10:39        1
# 1      2022-02-01 00:11:44 2022-02-01 07:44:39 2022-02-01 09:00:46       78
# 2      2022-02-01 00:12:27 2022-02-01 00:12:27 2022-02-01 00:12:39       68
# 3      2022-02-01 00:16:45 2022-02-01 04:43:31 2022-02-01 06:15:04       64
# 4      2022-02-01 00:17:49 2022-02-01 00:17:51 2022-02-01 00:58:55       64
# ...                    ...                 ...                 ...      ...
# 323211 2022-07-31 23:58:21 2022-08-01 00:02:54 2022-08-01 00:26:35       48
# 323212 2022-07-31 23:58:22 2022-08-01 00:03:31 2022-08-01 00:58:18       48
# 323213 2022-07-31 23:58:22 2022-08-01 00:03:31 2022-08-01 00:41:48       48
# 323214 2022-07-31 23:58:28 2022-08-01 03:57:32 2022-08-01 06:07:16      100
# 323215 2022-07-31 23:59:09 2022-08-01 04:03:54 2022-08-01 06:11:04      100
#
# ...

# %%
lookback = 5
lstm_inputall5, rows_to_discard5 = create_input_data.input_data_lstm(lookback, lstm_df)
# Out:
# *** loopback count never equals to  lookback. so do not consider the row 5
# *** loopback count never equals to  lookback. so do not consider the row 6

# %%
lstm_inputall5.shape
# Out:
# (323209, 5, 8)

# %%
rows_to_discard5
# Out:
# 6

# %%
lstm_inputall5[0:1,]
# Out:
# array([[[     16,       1,     330,       0,  133910,     142,   20383,
#          7955378],
#         [     16,       1,    2880,       0,  133980,     143,   20383,
#          7955378],
#         [     64,       1,      58,       0,  133980,     143,   20383,
#          7955378],
#         [     68,       1,       1,       0,  131240,     144,   20382,
#          7955377],
#         [      1,       1,    2880,       0,  131060,     143,   20382,
#          7955377]]])

# %%
lookback = 10
lstm_inputall10, rows_to_discard10 = create_input_data.input_data_lstm(lookback, lstm_df)
# Out:
# *** loopback count never equals to  lookback. so do not consider the row 10
# *** loopback count never equals to  lookback. so do not consider the row 11
# *** loopback count never equals to  lookback. so do not consider the row 12
# *** loopback count never equals to  lookback. so do not consider the row 13

# %%
lstm_inputall10.shape
# Out:
# (323202, 10, 8)

# %%
lstm_inputall10[0:2,]
# Out:
# array([[[      1,       1,     240,       0,  136270,     133,   20383,
#          7955378],
#         [      1,       1,     120,       0,  136390,     134,   20383,
#          7955378],
#         [      1,       1,    2880,       0,  136390,     134,   20383,
#          7955378],
#         [     50,       1,     120,       2,  136270,     133,   20383,
#          7955378],
#         [      1,       1,     240,       0,  136270,     133,   20383,
#          7955378],
#         [     16,       1,     330,       0,  133910,     142,   20383,
#          7955378],
#         [     16,       1,    2880,       0,  133980,     143,   20383,
#          7955378],
#         [     64,       1,      58,       0,  133980,     143,   20383,
#          7955378],
#         [     68,       1,       1,       0,  131240,     144,   20382,
#          7955377],
#         [      1,       1,    2880,       0,  131060,     143,   20382,
#          7955377]],
#
# ...

# %%
rows_to_discard10
# Out:
# 13

# %%
lstm_input3.shape
# Out:
# (5, 3, 8)

# %%
import numpy as np

# Write the array to disk
with open('test_lstm_input3.txt', 'w') as outfile:
    # I'm writing a header here just for the sake of readability
    # Any line starting with "#" will be ignored by numpy.loadtxt
    outfile.write('# Array shape: {0}\n'.format(lstm_input3.shape))
    
    # Iterating through a ndimensional array produces slices along
    # the last axis. This is equivalent to data[i,:,:] in this case
    for data_slice in lstm_input3:

        # The formatting string indicates that I'm writing out
        # the values in left-justified columns 7 characters in width
        # with 2 decimal places.  
        np.savetxt(outfile, data_slice, fmt='%-7.2f')

        # Writing out a break to indicate different slices...
        outfile.write('# New slice\n')

# %%
# Read the array from disk
new_data = np.loadtxt('test_lstm_input3.txt')

# Note that this returned a 2D array!
print(new_data.shape)

# However, going back to 3D is easy if we know the 
# original shape of the array
new_data = new_data.reshape((5, 3, 8))
    
# Just to check that they're the same...
assert np.all(new_data == lstm_input3)
# Out:
# (15, 8)

# %%
new_data.shape
# Out:
# (5, 3, 8)

# %%
lstm_input3
# Out:
# array([[[     64,       1,      58,       0,  133980,     143,   20383,
#          7955378],
#         [     68,       1,       1,       0,  131240,     144,   20382,
#          7955377],
#         [      1,       1,    2880,       0,  131060,     143,   20382,
#          7955377]],
#
#        [[     16,       1,    2880,       0,  133980,     143,   20383,
#          7955378],
#         [     64,       1,      58,       0,  133980,     143,   20383,
#          7955378],
#         [     68,       1,       1,       0,  131240,     144,   20382,
#          7955377]],
#
#        [[     16,       1,     330,       0,  133910,     142,   20383,
#          7955378],
#         [     16,       1,    2880,       0,  133980,     143,   20383,
#          7955378],
#         [     64,       1,      58,       0,  133980,     143,   20383,
#          7955378]],
#
#        [[     16,       1,     330,       0,  133910,     142,   20383,
#          7955378],
# ...

# %%
new_data
# Out:
# array([[[6.400000e+01, 1.000000e+00, 5.800000e+01, 0.000000e+00,
#          1.339800e+05, 1.430000e+02, 2.038300e+04, 7.955378e+06],
#         [6.800000e+01, 1.000000e+00, 1.000000e+00, 0.000000e+00,
#          1.312400e+05, 1.440000e+02, 2.038200e+04, 7.955377e+06],
#         [1.000000e+00, 1.000000e+00, 2.880000e+03, 0.000000e+00,
#          1.310600e+05, 1.430000e+02, 2.038200e+04, 7.955377e+06]],
#
#        [[1.600000e+01, 1.000000e+00, 2.880000e+03, 0.000000e+00,
#          1.339800e+05, 1.430000e+02, 2.038300e+04, 7.955378e+06],
#         [6.400000e+01, 1.000000e+00, 5.800000e+01, 0.000000e+00,
#          1.339800e+05, 1.430000e+02, 2.038300e+04, 7.955378e+06],
#         [6.800000e+01, 1.000000e+00, 1.000000e+00, 0.000000e+00,
#          1.312400e+05, 1.440000e+02, 2.038200e+04, 7.955377e+06]],
#
#        [[1.600000e+01, 1.000000e+00, 3.300000e+02, 0.000000e+00,
#          1.339100e+05, 1.420000e+02, 2.038300e+04, 7.955378e+06],
# ...

# %%
df_feb_1aug2022 = create_input_data.read_data(csv_file_name="../data/raw/anon_jobs_1Feb2022_1Aug2022_normal_sorted.csv", parse_dates_col=[4,5,6])
df_feb_1aug2022
# Out:
#            jobid                                               user  \
# 0        9084275  5a1c85eb8bc9d4da20ce12b96ecc7bb9d79d3ef991e990...
# 1        9084279  b4b4df9343fe9f7110ec15863fb5df13fbd20268383ba9...
# 2        9084280  c593da51b38e5fd95cb891ec53a4b70c41ca189bf4b92d...
# 3        9084291  db3b1cee65585e6744e72478a737eafaa23ce99e81344e...
# 4        9084294  bb3cdc72e4a6895d67d00ccd3c9cf0f65bdc59f32dfa9e...
# ...          ...                                                ...
# 323211  10056827  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323212  10056828  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323213  10056829  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323214  10056831  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
# 323215  10056833  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
#
#                                                   account      state  \
# 0       38112a802292edea407a0678c9c75259cba6473c7acc62...  COMPLETED
# ...

# %%
from importlib import reload
reload(create_input_data)
opt_df=build_features.remove_cols(df_feb_1aug2022,['jobid','end','account','state','user','reqcpus','nodelist'])
opt_df
# Out:
#                     submit               start  nnodes  max_minutes  \
# 0      2022-02-01 00:10:00 2022-02-01 00:10:02       1         2880
# 1      2022-02-01 00:11:44 2022-02-01 07:44:39       6          180
# 2      2022-02-01 00:12:27 2022-02-01 00:12:27       1            1
# 3      2022-02-01 00:16:45 2022-02-01 04:43:31       1         2880
# 4      2022-02-01 00:17:49 2022-02-01 00:17:51       1           58
# ...                    ...                 ...     ...          ...
# 323211 2022-07-31 23:58:21 2022-08-01 00:02:54       1          120
# 323212 2022-07-31 23:58:22 2022-08-01 00:03:31       1          120
# 323213 2022-07-31 23:58:22 2022-08-01 00:03:31       1          120
# 323214 2022-07-31 23:58:28 2022-08-01 03:57:32       2          180
# 323215 2022-07-31 23:59:09 2022-08-01 04:03:54       2          180
#
#         queue_minutes  backlog_minutes  backlog_num_jobs  running_num_jobs  \
# ...

# %%
def get_jobs_in_range(dfq,start,end):
    df1=dfq.query('submit >= @start and submit < @end')
    return df1

# %%
df_mar = get_jobs_in_range(opt_df,"2022-03-01", "2022-04-02")
df_mar
# Out:
#                    submit               start  nnodes  max_minutes  \
# 36043 2022-03-01 00:01:56 2022-03-01 00:01:57       1           15
# 36044 2022-03-01 00:01:57 2022-03-01 00:02:02       1           15
# 36045 2022-03-01 00:01:57 2022-03-01 00:02:02       1           15
# 36046 2022-03-01 00:01:58 2022-03-01 00:02:02       1           15
# 36047 2022-03-01 00:01:59 2022-03-01 00:02:02       1           15
# ...                   ...                 ...     ...          ...
# 82874 2022-04-01 23:40:41 2022-04-01 23:40:42       1          360
# 82875 2022-04-01 23:48:18 2022-04-01 23:48:19       5          720
# 82876 2022-04-01 23:48:55 2022-04-01 23:48:58       5          720
# 82877 2022-04-01 23:49:09 2022-04-01 23:49:09       5          720
# 82878 2022-04-01 23:49:27 2022-04-01 23:49:28       5          720
#
#        queue_minutes  backlog_minutes  backlog_num_jobs  running_num_jobs  \
# 36043              0           381027               234             20786
# ...

# %%
df_mar_reset=df_mar.reset_index()
df_mar_reset
# Out:
#        index              submit               start  nnodes  max_minutes  \
# 0      36043 2022-03-01 00:01:56 2022-03-01 00:01:57       1           15
# 1      36044 2022-03-01 00:01:57 2022-03-01 00:02:02       1           15
# 2      36045 2022-03-01 00:01:57 2022-03-01 00:02:02       1           15
# 3      36046 2022-03-01 00:01:58 2022-03-01 00:02:02       1           15
# 4      36047 2022-03-01 00:01:59 2022-03-01 00:02:02       1           15
# ...      ...                 ...                 ...     ...          ...
# 46831  82874 2022-04-01 23:40:41 2022-04-01 23:40:42       1          360
# 46832  82875 2022-04-01 23:48:18 2022-04-01 23:48:19       5          720
# 46833  82876 2022-04-01 23:48:55 2022-04-01 23:48:58       5          720
# 46834  82877 2022-04-01 23:49:09 2022-04-01 23:49:09       5          720
# 46835  82878 2022-04-01 23:49:27 2022-04-01 23:49:28       5          720
#
#        queue_minutes  backlog_minutes  backlog_num_jobs  running_num_jobs  \
# ...

# %%
from importlib import reload
reload(create_input_data)
lookback=5
col_name="queue_minutes"
vars=["nnodes",	"max_minutes","backlog_minutes","backlog_num_jobs","running_num_jobs","running_minutes"]

#df_mar_31,rows_to_discard=create_input_data.optimised_add_age_past_k_obs_insert(lookback, df_mar_reset,col_name)
df_lookback5,rows_to_discard=create_input_data.window_k_obs_all_vars_insert(lookback, df_mar_reset,col_name,vars)
# Out:
# *** loopback_count never equals to  lookback. so do not consider the row 0
# *** loopback_count never equals to  lookback. so do not consider the row 1
# *** loopback_count never equals to  lookback. so do not consider the row 2
# *** loopback_count never equals to  lookback. so do not consider the row 3
# *** loopback_count never equals to  lookback. so do not consider the row 4
# *** loopback_count never equals to  lookback. so do not consider the row 5
# *** loopback_count never equals to  lookback. so do not consider the row 6
# *** loopback_count never equals to  lookback. so do not consider the row 7
# *** loopback_count never equals to  lookback. so do not consider the row 8

# %%
df_lookback5
# Out:
#        index              submit               start  nnodes  max_minutes  \
# 0      36043 2022-03-01 00:01:56 2022-03-01 00:01:57       1           15
# 1      36044 2022-03-01 00:01:57 2022-03-01 00:02:02       1           15
# 2      36045 2022-03-01 00:01:57 2022-03-01 00:02:02       1           15
# 3      36046 2022-03-01 00:01:58 2022-03-01 00:02:02       1           15
# 4      36047 2022-03-01 00:01:59 2022-03-01 00:02:02       1           15
# ...      ...                 ...                 ...     ...          ...
# 46831  82874 2022-04-01 23:40:41 2022-04-01 23:40:42       1          360
# 46832  82875 2022-04-01 23:48:18 2022-04-01 23:48:19       5          720
# 46833  82876 2022-04-01 23:48:55 2022-04-01 23:48:58       5          720
# 46834  82877 2022-04-01 23:49:09 2022-04-01 23:49:09       5          720
# 46835  82878 2022-04-01 23:49:27 2022-04-01 23:49:28       5          720
#
#        queue_minutes  backlog_minutes  backlog_num_jobs  running_num_jobs  \
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/lookback5_sw_mar31.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
df_lookback5.to_csv(filepath,index=False)

# %%
### Get the data for March,April,May
### Remove some columns
df_feb_1aug2022 = create_input_data.read_data(csv_file_name="../data/raw/anon_jobs_1Feb2022_1Aug2022_normal_sorted.csv", parse_dates_col=[4,5,6])
df_feb_1aug2022
# Out:
#            jobid                                               user  \
# 0        9084275  5a1c85eb8bc9d4da20ce12b96ecc7bb9d79d3ef991e990...
# 1        9084279  b4b4df9343fe9f7110ec15863fb5df13fbd20268383ba9...
# 2        9084280  c593da51b38e5fd95cb891ec53a4b70c41ca189bf4b92d...
# 3        9084291  db3b1cee65585e6744e72478a737eafaa23ce99e81344e...
# 4        9084294  bb3cdc72e4a6895d67d00ccd3c9cf0f65bdc59f32dfa9e...
# ...          ...                                                ...
# 323211  10056827  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323212  10056828  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323213  10056829  4a4f2198bac2558f9e5a8c5eb68e7ba4a163c55ce93e37...
# 323214  10056831  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
# 323215  10056833  4c6876a9c556f9039eb938f387f82f71400b3eafa372b2...
#
#                                                   account      state  \
# 0       38112a802292edea407a0678c9c75259cba6473c7acc62...  COMPLETED
# ...

# %%
from importlib import reload
reload(create_input_data)
opt_df=build_features.remove_cols(df_feb_1aug2022,['jobid','end','account','state','user','reqcpus','nodelist'])
opt_df
# Out:
#                     submit               start  nnodes  max_minutes  \
# 0      2022-02-01 00:10:00 2022-02-01 00:10:02       1         2880
# 1      2022-02-01 00:11:44 2022-02-01 07:44:39       6          180
# 2      2022-02-01 00:12:27 2022-02-01 00:12:27       1            1
# 3      2022-02-01 00:16:45 2022-02-01 04:43:31       1         2880
# 4      2022-02-01 00:17:49 2022-02-01 00:17:51       1           58
# ...                    ...                 ...     ...          ...
# 323211 2022-07-31 23:58:21 2022-08-01 00:02:54       1          120
# 323212 2022-07-31 23:58:22 2022-08-01 00:03:31       1          120
# 323213 2022-07-31 23:58:22 2022-08-01 00:03:31       1          120
# 323214 2022-07-31 23:58:28 2022-08-01 03:57:32       2          180
# 323215 2022-07-31 23:59:09 2022-08-01 04:03:54       2          180
#
#         queue_minutes  backlog_minutes  backlog_num_jobs  running_num_jobs  \
# ...

# %%
df_mar_may = get_jobs_in_range(opt_df,"2022-03-01", "2022-06-01")
df_mar_may
# Out:
#                     submit               start  nnodes  max_minutes  \
# 36043  2022-03-01 00:01:56 2022-03-01 00:01:57       1           15
# 36044  2022-03-01 00:01:57 2022-03-01 00:02:02       1           15
# 36045  2022-03-01 00:01:57 2022-03-01 00:02:02       1           15
# 36046  2022-03-01 00:01:58 2022-03-01 00:02:02       1           15
# 36047  2022-03-01 00:01:59 2022-03-01 00:02:02       1           15
# ...                    ...                 ...     ...          ...
# 198855 2022-05-31 23:47:46 2022-06-01 01:02:47       6          360
# 198856 2022-05-31 23:49:38 2022-06-01 01:03:11       1         2600
# 198857 2022-05-31 23:50:04 2022-05-31 23:57:46       6         1200
# 198858 2022-05-31 23:50:04 2022-06-01 01:03:11       1         2600
# 198859 2022-05-31 23:55:22 2022-06-01 01:03:18       2          720
#
#         queue_minutes  backlog_minutes  backlog_num_jobs  running_num_jobs  \
# ...

# %%
df_mar_may_reset=df_mar_may.reset_index()
df_mar_may_reset
# Out:
#          index              submit               start  nnodes  max_minutes  \
# 0        36043 2022-03-01 00:01:56 2022-03-01 00:01:57       1           15
# 1        36044 2022-03-01 00:01:57 2022-03-01 00:02:02       1           15
# 2        36045 2022-03-01 00:01:57 2022-03-01 00:02:02       1           15
# 3        36046 2022-03-01 00:01:58 2022-03-01 00:02:02       1           15
# 4        36047 2022-03-01 00:01:59 2022-03-01 00:02:02       1           15
# ...        ...                 ...                 ...     ...          ...
# 162812  198855 2022-05-31 23:47:46 2022-06-01 01:02:47       6          360
# 162813  198856 2022-05-31 23:49:38 2022-06-01 01:03:11       1         2600
# 162814  198857 2022-05-31 23:50:04 2022-05-31 23:57:46       6         1200
# 162815  198858 2022-05-31 23:50:04 2022-06-01 01:03:11       1         2600
# 162816  198859 2022-05-31 23:55:22 2022-06-01 01:03:18       2          720
#
# ...

# %%
from importlib import reload
reload(create_input_data)
lookback=15
col_name="queue_minutes"
vars=["nnodes",	"backlog_num_jobs"]

#df_mar_31,rows_to_discard=create_input_data.optimised_add_age_past_k_obs_insert(lookback, df_mar_reset,col_name)
df_lookback15,rows_to_discard=create_input_data.window_k_obs_all_vars_insert(lookback, df_mar_may_reset,col_name,vars)
# Out:
# *** loopback_count never equals to  lookback. so do not consider the row 0
# *** loopback_count never equals to  lookback. so do not consider the row 1
# *** loopback_count never equals to  lookback. so do not consider the row 2
# *** loopback_count never equals to  lookback. so do not consider the row 3
# *** loopback_count never equals to  lookback. so do not consider the row 4
# *** loopback_count never equals to  lookback. so do not consider the row 5
# *** loopback_count never equals to  lookback. so do not consider the row 6
# *** loopback_count never equals to  lookback. so do not consider the row 7
# *** loopback_count never equals to  lookback. so do not consider the row 8
# *** loopback_count never equals to  lookback. so do not consider the row 9
# *** loopback_count never equals to  lookback. so do not consider the row 10
# *** loopback_count never equals to  lookback. so do not consider the row 11
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/lookback15_sw_mar_may31.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
df_lookback15.to_csv(filepath,index=False)

# %%
df_lookback15_age_input = df_lookback15.iloc[61:,:]
df_lookback15_age_input=df_lookback15_age_input.reset_index(drop=True)

# %%
#df_lookback15_age,rows_to_discard_age = create_input_data.optimised_add_total_age_nodes_past_k_obs_insert(15,df_lookback15_age_input,"queue_minutes")

# %%
#df_lookback15_age_input

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/lookback15_age_nodes_sw_mar_may31.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
df_lookback15.to_csv(filepath,index=False)

# %%
from importlib import reload
reload(create_input_data)
lookback=35
col_name="queue_minutes"
vars=["nnodes",	"backlog_num_jobs"]

df_feb_1aug2022 = create_input_data.read_data(csv_file_name="../data/raw/anon_jobs_1Feb2022_1Aug2022_normal_sorted.csv", parse_dates_col=[4,5,6])
opt_df=build_features.remove_cols(df_feb_1aug2022,['jobid','end','account','state','user','reqcpus','nodelist'])
df_mar_may = get_jobs_in_range(opt_df,"2022-03-01", "2022-06-01")
df_mar_may_reset=df_mar_may.reset_index()
#df_mar_may_reset
#df_mar_31,rows_to_discard=create_input_data.optimised_add_age_past_k_obs_insert(lookback, df_mar_reset,col_name)
df_lookback35,rows_to_discard=create_input_data.window_k_obs_all_vars_insert(lookback, df_mar_may_reset,col_name,vars)
# Out:
# *** loopback_count never equals to  lookback. so do not consider the row 0
# *** loopback_count never equals to  lookback. so do not consider the row 1
# *** loopback_count never equals to  lookback. so do not consider the row 2
# *** loopback_count never equals to  lookback. so do not consider the row 3
# *** loopback_count never equals to  lookback. so do not consider the row 4
# *** loopback_count never equals to  lookback. so do not consider the row 5
# *** loopback_count never equals to  lookback. so do not consider the row 6
# *** loopback_count never equals to  lookback. so do not consider the row 7
# *** loopback_count never equals to  lookback. so do not consider the row 8
# *** loopback_count never equals to  lookback. so do not consider the row 9
# *** loopback_count never equals to  lookback. so do not consider the row 10
# *** loopback_count never equals to  lookback. so do not consider the row 11
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/lookback35_nnodes_bklogjobs_sw_mar_may31.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
df_lookback35.to_csv(filepath,index=False)

# %%
from importlib import reload
reload(create_input_data)
lookback=35  (discard column 77)
col_name="queue_minutes"
#vars=["nnodes",	"backlog_num_jobs"]

df_Jan_1Feb2022 = create_input_data.read_data(csv_file_name="../data/raw/anon_jobs_1Jan2022_1Feb2022_normal_sorted.csv", parse_dates_col=[4,5,6])
#opt_df=build_features.remove_cols(df_Jan_1Feb2022,['jobid','end','account','state','user','reqcpus','nodelist'])
df_jan = get_jobs_in_range(df_Jan_1Feb2022,"2022-01-01", "2022-02-01")
df_jan_reset=df_jan.reset_index(drop=True)
#df_jan_reset
#df_mar_may_reset
#df_mar_31,rows_to_discard=create_input_data.optimised_add_age_past_k_obs_insert(lookback, df_mar_reset,col_name)
df_lookback35,rows_to_discard=create_input_data.optimised_add_past_k_obs_insert(lookback, df_jan_reset,col_name)
# Out:
# *** loopback_count never equals to  lookback. so do not consider the row 0
# *** loopback_count never equals to  lookback. so do not consider the row 1
# *** loopback_count never equals to  lookback. so do not consider the row 2
# *** loopback_count never equals to  lookback. so do not consider the row 3
# *** loopback_count never equals to  lookback. so do not consider the row 4
# *** loopback_count never equals to  lookback. so do not consider the row 5
# *** loopback_count never equals to  lookback. so do not consider the row 6
# *** loopback_count never equals to  lookback. so do not consider the row 7
# *** loopback_count never equals to  lookback. so do not consider the row 8
# *** loopback_count never equals to  lookback. so do not consider the row 9
# *** loopback_count never equals to  lookback. so do not consider the row 10
# *** loopback_count never equals to  lookback. so do not consider the row 11
# ...

# %%
# write to file
from pathlib import Path  
filepath = Path('../data/processed/lookback35_anon_jan1_feb1.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
df_lookback35.to_csv(filepath,index=False)

# %%
df_lookback35
# Out:
#          jobid                                               user  \
# 0      8966735  63efbc460b9d86577ac4a6a795b844ed63b9402f4fec7b...
# 1      8966746  1f138da1b8259d0693edf87e7bd0ddd3b9aa9890c9258b...
# 2      8966750  8a74d070230571d06c8053d86b392627fc16ea9da83579...
# 3      8966755  8a74d070230571d06c8053d86b392627fc16ea9da83579...
# 4      8966756  499b05f4c4fa3275b699c4148fd8ad155b80b1ff6e74eb...
# ...        ...                                                ...
# 33492  9084244  1aba0f04a36f9b1540c05b94994916b5260800620cffd9...
# 33493  9084248  1aba0f04a36f9b1540c05b94994916b5260800620cffd9...
# 33494  9084249  1aba0f04a36f9b1540c05b94994916b5260800620cffd9...
# 33495  9084250  1aba0f04a36f9b1540c05b94994916b5260800620cffd9...
# 33496  9084251  1e28cab4a3a687f56bb0f3b2f8dc0f45bcbdeb49fdfbce...
#
#                                                  account      state  \
# 0      21d123703106994fa0581e31a03015aabdc2720ed243f5...  COMPLETED
# ...
